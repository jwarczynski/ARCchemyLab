# %%
import json
import random

from visualization import plot_challenge_examples

# %%
path = 'data/arc-agi_training_challenges.json'
with open(path, 'r') as f:
    training_challenges = json.load(f)

# %%
keys = list(training_challenges.keys())

# %%
key = random.choice(list(training_challenges.keys()))
examples = training_challenges[key]['train']
plot_challenge_examples(examples)
